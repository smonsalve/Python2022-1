# %%
#Write a function that takes three numbers as parameters, and returns the median value
#of those parameters as its result. Include a main program that reads three values from
#the user and displays their median.
# le agrege que pudiera ingresar n cantidad de elementos a la lista.
#que tambien funcione para listas de longitud par e impar.

listaNum=[]
#para ingresar numeros a la lista
valor = int(input("la lsita se detiene al ingresar 0, Por favor ingrese un número:"))

while(valor != 0):
  listaNum.append(valor)
  valor = int(input("la lsita se detiene al ingresar 0, Por favor ingrese un número: ",))

n = len(listaNum) # longitud de la lsita
listaNum.sort()  # aqui la ordena de mayor a menor
print("numeros ordenados de mayor a menor: ", listaNum)
#saber si la lista es par o impar
# en caso de la lista ser par imprimira los dos numeros correspondientes a la mediana

if n%2 != 0: #para listas impares
    m=int((n+1)/2) #fromual matematica para hallar la mediana
    mediana=listaNum.pop(m-1) # se agrega un -1 para poder en contrar la ubicación  de la mediana 

    print("la mediana de esta lista es el número:", mediana)

else: #para listas pares
    m=int(n/2)
    mediana=listaNum.pop(m-1)
    mediana2=listaNum.pop(m)
    print("la mediana de esta lista son los siguientes numeros: ", mediana, "y", mediana2)
# Out:
# la lsita se detiene al ingresar 0, Por favor ingrese un número:8
# la lsita se detiene al ingresar 0, Por favor ingrese un número: 9
# la lsita se detiene al ingresar 0, Por favor ingrese un número: 7
# la lsita se detiene al ingresar 0, Por favor ingrese un número: 6
# la lsita se detiene al ingresar 0, Por favor ingrese un número: 0
# numeros ordenados de mayor a menor:  [6, 7, 8, 9]
# la mediana de esta lista son los siguientes numeros:  7 y 9
