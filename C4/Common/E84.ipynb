# %%
#Write a function that takes three numbers as parameters, and returns the median value
#of those parameters as its result. Include a main program that reads three values from
#the user and displays their median.

a = int(input("ingrese el primer número: "))
b = int(input("ingrese el segundo número: "))
c = int(input("ingrese el tercer número: "))

d = max(a, b, c)
e = min(a, b, c)
f = a+b+c-d-e

# print("el menor:", e)
# print("el de la mitad:", f)
# print("el mayor :", d)
print("los numeros ordenados de menor a mayor: ", e, f, d)
print("la mediana es :", f)
# Out:
# ingrese el primer número: 1
# ingrese el segundo número: 2
# ingrese el tercer número: 3
# los numeros ordenados de menor a mayor:  1 2 3
# la mediana es : 2
